# %%
lista = [10, 58, 18, 62, 41, 68, 32, 74, 101, 574, 456, 3, 85, 12, 26, 97, 46]
maiores_de_50 = [ ]

for n in lista:
  if n > 50:
    maiores_de_50.append(n)

print(maiores_de_50)
# Out:
# [58, 62, 68, 74, 101, 574, 456, 85, 97]

# %%
idades = [10, 12, 14, 52, 74, 63, 31, 19, 50, 9, 85, 54, 39, 24]
maiores_de_18 = []

for n in idades:
  if n >= 18:
    maiores_de_18.append(n)

print(maiores_de_18)
# Out:
# [52, 74, 63, 31, 19, 50, 85, 54, 39, 24]

# %%
numeros = [3, 8, 15, 20, 7, 12, 9, 30]
numeros_pares = []

for n in numeros:
  if n % 2 == 0:
    numeros_pares.append(n)

print(numeros_pares)
# Out:
# [8, 20, 12, 30]

# %%
valores = [22, 55, 13, 80, 42, 67, 10]
contador = 0

for n in valores:
    if n >= 50:
        contador += 1

print(contador)
# Out:
# 3

# %%
numeros = [12, 45, 60, 23, 90, 11, 54]

maiores = []

for n in numeros:
  if n > 50:
    maiores.append(n)

print(maiores)
# Out:
# [60, 90, 54]

# %%
valores = [7, 18, 21, 44, 59, 62, 33]

numeros_pares = []

for n in valores:
  if n % 2 == 0:
    numeros_pares.append(n)

print(numeros_pares)
# Out:
# [18, 44, 62]

# %%
idades = [15, 22, 17, 30, 14, 19, 40]
contador = 0

for n in idades:

 if n > 18:
  contador += 1


print(contador)
# Out:
# 4

# %%
notas = [6, 8, 7, 9, 5]
media = sum(notas) / len(notas)

print(media)
# Out:
# 7.0
